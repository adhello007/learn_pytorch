# %%
import torch

# %% [markdown]
# Introduction to Tensors

# %%
#scalar tensor
scalar = torch.tensor(7)

# %%
scalar.ndim
# Out:
# 0

# %%
scalar.shape
# Out:
# torch.Size([])

# %%
a = scalar.item() #converts a tensor back to a python variable like int, string etc.

# %%
type(a)
# Out:
# int

# %%
#vector 
vector = torch.tensor([3,4])

# %%
vector.ndim
# Out:
# 1

# %%
vector.shape #this means that there is one dimension with 2 elements
# Out:
# torch.Size([2])

# %%
#matrix 
MATRIX = torch.tensor([[3,4],
                       [2,8]])

# %%
MATRIX.ndim
# Out:
# 2

# %%
MATRIX.shape
# Out:
# torch.Size([2, 2])

# %%
#TENSOR
tenso = torch.tensor([[[1,2,3,4],
                       [3,1,4,4],
                       [1,3,6,7]]])

# %%
tenso.ndim
# Out:
# 3

# %%
tenso.shape
# Out:
# torch.Size([1, 3, 4])

# %%
exp = torch.tensor([[[[3,4,5],
                      [3,4,5],
                      [3,4,5]],
                      [[3,4,5],
                      [3,4,5],
                      [3,4,5]]],])

# %%
exp.ndim
# Out:
# 4

# %%
exp.shape
# Out:
# torch.Size([1, 2, 3, 3])
