# %% [markdown]
# How to Adjust the shapes of PRE-EXISTING TENSORS. How to Modify them.

# %%
import torch

# %% [markdown]
# TRANSPOSE FUNCTION IS HELPFUL IN MANIPULATING EXISTING TENSORS

# %%
tensor_a = torch.tensor([[3,6,9],
                         [8,16,24],
                         [13,26,39]])
tensor_a
# Out:
# tensor([[ 3,  6,  9],
#         [ 8, 16, 24],
#         [13, 26, 39]])

# %%
tensor_a= tensor_a.unsqueeze(dim=0)

# %%
tensor_a.shape #added this extra 1 dimension by wrapping in another square bracket
# Out:
# torch.Size([1, 3, 3])

# %%
a_transpose = tensor_a.T
print(a_transpose)
# Out:
# tensor([[[ 3],
#          [ 8],
#          [13]],
#
#         [[ 6],
#          [16],
#          [26]],
#
#         [[ 9],
#          [24],
#          [39]]])
# /tmp/ipykernel_2720/3196989828.py:1: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3683.)
#   a_transpose = tensor_a.T

# %%
a_transpose.shape
# Out:
# torch.Size([3, 3, 1])
