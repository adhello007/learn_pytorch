# %%
import torch

# %%
#Squeeze: 

x = torch.zeros(2,1,2,1,2)
x, x.shape
# Out:
# (tensor([[[[[0., 0.]],
#
#            [[0., 0.]]]],
#
#
#
#          [[[[0., 0.]],
#
#            [[0., 0.]]]]]),
#  torch.Size([2, 1, 2, 1, 2]))

# %%
#all 1 dimensions are gone :

y = torch.squeeze(x)
y, y.shape
# Out:
# (tensor([[[0., 0.],
#           [0., 0.]],
#
#          [[0., 0.],
#           [0., 0.]]]),
#  torch.Size([2, 2, 2]))

# %%
z = torch.squeeze(x,0)
z, z.shape
# Out:
# (tensor([[[[[0., 0.]],
#
#            [[0., 0.]]]],
#
#
#
#          [[[[0., 0.]],
#
#            [[0., 0.]]]]]),
#  torch.Size([2, 1, 2, 1, 2]))

# %%
#Permute for Images 

x_original = torch.rand(size=(224,224,3)) #height, width, channels 
x_original.shape
# Out:
# torch.Size([224, 224, 3])

# %%
#we will convert it to channels, height, width 
x_permuted = x_original.permute(2,0,1) #channles, height, width 
x_permuted.shape
# Out:
# torch.Size([3, 224, 224])

# %%
import numpy as np 
np_x = x_original.numpy()

# %%
np_x = (np_x*255).astype(np.uint8)

# %%
from PIL import Image 
image = Image.fromarray(np_x)

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>
